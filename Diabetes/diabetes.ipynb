# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("C:/Users/A/diabetes.csv")
df
# Out:
#       Unnamed: 0  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0              0            2      138             62             35        0
# 1              1            0       84             82             31      125
# 2              2            0      145              0              0        0
# 3              3            0      135             68             42      250
# 4              4            1      139             62             41      480
# ...          ...          ...      ...            ...            ...      ...
# 1334        1974            1      153             82             42      485
# 1335        1975            8      188             78              0        0
# 1336        1976            7      152             88             44        0
# 1337        1977            2       99             52             15       94
# 1338        1978            1      109             56             21      135
#
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0  Pregnancies      Glucose  BloodPressure  SkinThickness  \
# count  1339.000000  1339.000000  1339.000000    1339.000000    1339.000000
# mean    951.263630     3.752801   121.083645      69.126960      20.844660
# std     667.597467     3.325983    31.855764      19.224199      16.062511
# min       0.000000     0.000000     0.000000       0.000000       0.000000
# 25%     334.500000     1.000000    99.500000      62.000000       0.000000
# 50%     702.000000     3.000000   117.000000      72.000000      23.000000
# 75%    1608.500000     6.000000   141.000000      80.000000      32.500000
# max    1978.000000    17.000000   199.000000     122.000000     110.000000
#
#            Insulin          BMI  DiabetesPedigreeFunction          Age  \
# count  1339.000000  1339.000000               1339.000000  1339.000000
# mean     79.851382    32.184615                  0.474176    33.007468
# std     113.512132     8.128558                  0.328254    11.703101
# ...

# %%
df.shape
# Out:
# (1339, 10)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                  0
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
category_column=df.select_dtypes(include=['object']).columns.tolist()
category_column
# Out:
# []

# %%
df.to_csv("C:/Users/A/Diabetes.csv",index=False)
